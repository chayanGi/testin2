# %% [markdown]
# Attrition:- the phenomenon of the employees leaving the company.
#
# __Possible Reasons:-__
#    - Long working hours.
#    - Incompetent management
#    - Sickness or Death of an employee
#    - Better opportunities for employees outside the organization.
#    - Negative working environment.

# %%
#importinig all the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#We are using Seaborn library for Data visualization.
#Seaborn is a library for making attractive and informative statistical graphics in Python.
#It is built on top of matplotlib and tightly integrated with the PyData stack, including support for numpy
#and pandas data structures and statistical routines from scipy and statsmodels.

# %%
#loading dataset...
df = pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#checking if their are any missing values
display(df.isnull().any())
##no missing data

#checking the size of the dataset
df.shape
##we have 35 observations for 1470 columns
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EmployeeCount               False
# EmployeeNumber              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# Over18                      False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StandardHours               False
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#what are the datatypes of values we have?
df.dtypes
#our observation is either an integer or categorical
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# ***

# %%
#visualizing our observational points
df.hist(figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f83ec9e1ac8>,
# ...
#       dtype=object)

# %% [markdown]
# ### observations based on histograms
# - Several numerical features are tail-heacy.
#     - MonthyIncome, DiscanceFromHome, YearAtCompany are right-skewed, therefore Data transformation methods may be required to approach a normal distribution before training a model for the data.
# - Age distribution is slightly right-skewed normal distribution with the bulf of staf between 25 and 45 years old.
# - EmployeeCount and StandardHours are constant throughout the data hence needed to be dropped.
# - Employee number is a private key for employees.

# %%
#what different types of categories we have for our categorical variables.
cat_val = []
for c in df.columns:
    if df[c].dtype == object:
        cat_val.append(c)
        print(c, '->',df[c].unique())
# Out:
# Attrition -> ['Yes' 'No']
# BusinessTravel -> ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Department -> ['Sales' 'Research & Development' 'Human Resources']
# EducationField -> ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Gender -> ['Female' 'Male']
# JobRole -> ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# MaritalStatus -> ['Single' 'Married' 'Divorced']
# Over18 -> ['Y']
# OverTime -> ['Yes' 'No']

# %%
#removing useless columns
df.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis='columns', inplace=True)
cat_val.remove('Over18')

# %%
#changing category of Attrition to Binary
df['Attrition'] = df['Attrition'].map(lambda x: 1 if x=='Yes' else 0)

# %% [markdown]
# ***

# %%
A_rate = df.Attrition.value_counts()

sns.countplot(df['Attrition'])
plt.text(x = -.15, y = 800, s = str(np.round(A_rate[0]/df.shape[0], 4) * 100) + '%', fontsize = 16)
plt.text(x = .85, y = 100, s = str(np.round(A_rate[1]/df.shape[0], 4) * 100) + '%', fontsize = 16)
plt.xticks(np.arange(2),('No', 'Yes'))
plt.show()

# %% [markdown]
# This implies that our data is unbalanced.
# 84% of the employees stayed in the Company whereas 16% left the company. This will help us in selecting the model for predicting Attrition.

# %% [markdown]
# <font color=red><h1>Analysis by Age</h1></font>
# Every generation have their differences and these should be explored in this dataset.
# let's designate the generation as follows:
# - Generation A:- Age>=18 and Age<38
# - Generation B:- Age>=38 and Age<54
# - Generation C:- Age>=54 and Age<73
# - Generation D:- Age>=73

# %%
df['Age_Range']=pd.cut(df['Age'],[18, 37,54,73,120])
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(x='Age_Range',hue='Attrition',data=df)

# %% [markdown]
# This shows that young employees are more prone to leaving the organization and older employees leave mostly due to death or retirement.
# The employees in theie 40s tend to stay.

# %%
#since age is a continuous value, we can plot it against Attrition
sns.catplot(data=df, y='Age', x='Attrition', height=5, aspect=1, kind='box')

# %% [markdown]
# This is one more proof of Attrition in young generation being greater.
# The people who stayed in the organization have higher median and higher maximum age of people than the people who left the organization.
# This shows that people with more age have lesser tendency to leave as compared to the relatively young employees.

# %%
fig=plt.figure(figsize=(15,4))
ax=sns.kdeplot(df.loc[(df['Attrition']==0),'YearsAtCompany'],color='g',shade=False,label='No Attrition')
ax=sns.kdeplot(df.loc[(df['Attrition']==1),'YearsAtCompany'],color='r',shade=True,label='Attrition')
ax.set(xlabel='Employee YearsAtCompany ',ylabel='Frequency')
plt.title('Employee YearsAtCompany - Attrition vs No Attrition')
#This plot also conferms the above mentioned observations
# Out:
# Text(0.5, 1.0, 'Employee YearsAtCompany - Attrition vs No Attrition')

# %%
plt.figure(figsize=(20, 4))
sns.countplot(x=df.loc[df.Attrition==1].EducationField)
plt.show()
a=sns.barplot(x=df.Education.unique(), y=df.groupby('Education')['Age'].mean(), data=df)
a.set(xlabel='Education')
plt.show()

# %% [markdown]
# This give the idea that more Employees from Life Sciences background field as compared to others.
# Employee's age does not give any idea about his/her qualification.

# %% [markdown]
# <font color=red><h1>Gender Analysis</h1></font>

# %%
sns.countplot(x=df.loc[df.Attrition==1].Gender)
#Attrition is more among male employees.

# %%
sns.barplot(x='Attrition',y='MonthlyIncome',hue='Gender',data=df)
plt.show()
sns.barplot(x=np.sort(df.Attrition.unique()), y=df.groupby('Attrition').mean()['MonthlyIncome'])
plt.show()
#Monthly income by gender is quite comparable, but monthly income of
#those who left the organization is significantly less than those who stayed.

# %%
sns.countplot(x=df.loc[df['Attrition']==1]['DistanceFromHome'],hue='Gender',data=df)
#People who live further away from their work show higher proportion of leavers compared to their counterparts.

# %% [markdown]
# <font color=red><h1>Income</h1></font>
# To analyze the importance of income among employees and how it affects attrition.
# Questions:
# 1. Average Monthly Income by department? Does Attrition get affected by this?
#     - Significant difference in attrition from individual departments. HealthCare Representatives, Sales Representatives and Research Scientists have the highest DailyRate differences in relation with Attrition. It is safe to assume that atleast for these departments, the monthly income influences the Attrition.
# 2. Is their any relation between JobSatisfaction levels and Income of individuals?
#     - Lower the job satisfaction the wider the gap by attrition status in the level of income.
# 4. Is their any financial endorsment for employee with higher performance ratings?
#     - Most of the employees who left the organization had less than 15% hike and monthly income less than 7000.
# 5. Does exhaustion causes Attrition?
#     - Over 54% of workers who left the organization worked overtime, this can be one of the reasons for Attrition.

# %%
df['Income_Range']=pd.cut(df['MonthlyIncome'],[1000,5000,10000,15000,20000])
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(x='Income_Range',hue='Attrition',data=df).set_title('Employee Salary Attrition Distribution')
plt.show()

# %%
zero = df.loc[df['Attrition']==0].groupby('Department').mean()['MonthlyIncome']
one = df.loc[df['Attrition']==1].groupby('Department').mean()['MonthlyIncome']
for index in (0, 1):
    axIncome=sns.barplot(y=df.loc[df['Attrition']==index].groupby('Department').mean()['MonthlyIncome'], x=df.Department.unique())
    axIncome.set_xticklabels(axIncome.get_xticklabels(), rotation=45)
    plt.title('Attrition= '+str(index))
    plt.show()
axIncome=sns.countplot(x=df.loc[df.Attrition==1].Department)
axIncome.set_xticklabels(axIncome.get_xticklabels(), rotation=45)
plt.show()

# %%
import requests

payload = {
    "max_discount": "0.3",
    "min_discount": "0.04",
    "sl_weeks": "13",
    "...": "..."
}

headers = {
    "Content-Type": "application/json",
    "BearerToken": "orawCeF2FSrJwqQ4vmf4WGFFXqEWEoVK",
    "...": "..."
}

url = "prod-123.region.logic.azure.com"


response = requests.post(url=url, payload=payload, headers=headers)

if response.status_code == 200:
    print(response.json())
# Out:
# Jupyter cannot be started. Error attempting to locate jupyter: Running cells with 'Python 3.9.10 64-bit' requires jupyter and notebook package.
#
# Run the following command to install 'jupyter and notebook' into the Python environment.
#
# Command: 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Click <a href='https://aka.ms/installJupyterForVSCode'>here</a> for more info.

# %%
fig=plt.figure(figsize=(15,4))
ax=sns.kdeplot(df.loc[(df['Attrition']==0),'JobSatisfaction'],color='g',shade=False,label='No Attrition')
ax=sns.kdeplot(df.loc[(df['Attrition']==1),'JobSatisfaction'],color='r',shade=True,label='Attrition')
ax.set(xlabel='Employee Job Satisfaction Rating',ylabel='Frequency')
plt.title('Employee Job Satisfaction Rating - Attrition vs No Attrition')
# Out:
# Text(0.5, 1.0, 'Employee Job Satisfaction Rating - Attrition vs No Attrition')

# %%
fig=plt.figure(figsize=(10,6))
sns.countplot(x='YearsSinceLastPromotion',hue='Attrition',data=df)
plt.show()
#this supports the above inference which mentions hike<15% among most employees who left.

# %%
sns.countplot(x=df.loc[df['Attrition']==1]['OverTime'])
#Out of those who left the organization most employees worked overtime

# %% [markdown]
# <font color=red><h1>Working Environment</h1></font>

# %%
fig=plt.figure(figsize=(10,6))
sns.countplot(x='YearsWithCurrManager',hue='Attrition',data=df)
plt.show()
#employees probably get used to the manager and this factor becomes less significant overtime in promoting Attrition.

# %%
sns.countplot(df.loc[df['Attrition']==1]['BusinessTravel'])
#Attrition is more among Frequent Business Travellers

# %%
sns.countplot(df.loc[df['Attrition']==1]['Education'])
#employees with bachelors degree are more inclined towards attrition.

# %% [markdown]
# <font color=red><h1>more</h1></font>
# ### Inferences
# - WorkLifeBalance Rating shows that Attrition is less in lower and higher spectrum of ratings.
# - Single Employees have more tendency to leave the organization.
# - RelationshipSatisfaction and WorkLifeBalance gives somewhat similar trends.
# - Sales Executive, Research Scientist and Laboratory Technician Role sees more Attriton.

# %%
fig=plt.figure(figsize=(15,4))
ax=sns.kdeplot(df.loc[(df['Attrition']==0),'WorkLifeBalance'],color='g',shade=False,label='No Attrition')
ax=sns.kdeplot(df.loc[(df['Attrition']==1),'WorkLifeBalance'],color='r',shade=True,label='Attrition')
ax.set(xlabel='Employee WorkLifeBalance Rating',ylabel='Frequency')
plt.title('Employee WorkLifeBalance Rating - Attrition vs No Attrition')
# Out:
# Text(0.5, 1.0, 'Employee WorkLifeBalance Rating - Attrition vs No Attrition')

# %%
sns.countplot(x=df['MaritalStatus'], hue='Attrition', data=df)

# %%
fig=plt.figure(figsize=(15,4))
ax=sns.kdeplot(df.loc[(df['Attrition']==0),'RelationshipSatisfaction'],color='g',shade=False,label='No Attrition')
ax=sns.kdeplot(df.loc[(df['Attrition']==1),'RelationshipSatisfaction'],color='r',shade=True,label='Attrition')
ax.set(xlabel='Employee RelationshipSatisfaction Rating',ylabel='Frequency')
plt.title('Employee Relationship Satisfaction Rating - Attrition vs No Attrition')
# Out:
# Text(0.5, 1.0, 'Employee Relationship Satisfaction Rating - Attrition vs No Attrition')

# %%
fig=plt.figure(figsize=(30, 4))
sns.countplot(x=df.JobRole, hue=df.Attrition)

# %% [markdown]
# <font color=red><h1>Correlation Matrix</h1></font>

# %%
f,ax = plt.subplots(figsize=(20, 20))
sns.heatmap(df.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %% [markdown]
# ### heatmap function
#  - .corr() method returns a correlation data frame containing the correlation values between the various attributes.
#  - next we pass necessary parameters to the heatmap function.
#      - annot: bool
#          - whether to display values on top of square or not. In order to display pass it either True or df.corr()
#      - linewidths: float, optional
#          - width of the lines that will divide each cell
#      - ax: matplotlib Axes, optional
#          - Axes in which to draw the plot, otherwise use the currently-active Axes.
#      - fmt: string, optional
#          - String formatting code to use when adding annotations
#  - returns ax: matplotlib Axes
#       - Axes object with the heatmap.
#
# ## Inferences from the Heatmap
#
# - Self relation is equal to 1 as expected.
# - YearsAtCompany is related to YearsInCurrentRole
# - JobLevel is highly correlated to Age as aged employees will generally tend to occupy higher positions in an organization.
# - YearsWithCurrManager is highly related to YearsAtCompany
# - PerformanceRating is highly correlated to PercentSalaryHike.
# - TotalWorkingYears is highly related to JobLevel means senior employees must have worked for more number of years.
# - MonthlyIncome is highly correlated to JobLevel as senior employees will obviously earn more.

# %% [markdown]
# Since we have 34 features consisting of Categorical and Numerical values, the target varirable i.e. Attrition of employee can either be 'Yes' or 'No'.
# Hence this is a Binary Classification Problem.
